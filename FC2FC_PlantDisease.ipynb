# %% [markdown]
# کد مربوط به مقاله ارسالی درخصوص تبدیل لایه‌های طبقه‌بند تمام متصل به پیچشی
#
# M. Amintoosi

# %%
import keras
from keras import layers
from keras import models
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
# This is module with image preprocessing utilities
from keras.preprocessing import image
from keras.layers import BatchNormalization
import tensorflow as tf
from keras.callbacks import ModelCheckpoint
keras.__version__
# Out:
# '2.14.0'

# %%
import os, shutil
from os import listdir
from os.path import isfile, join
from pathlib import Path
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import math
import seaborn as sns

tf.random.set_seed(3)

# %%
# !pip install python-bidi
# !pip install arabic-reshaper
# !pip install pycm
from pycm import *
# Out:
# Collecting python-bidi
#   Downloading python_bidi-0.4.2-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from python-bidi) (1.16.0)
# Installing collected packages: python-bidi
# Successfully installed python-bidi-0.4.2
# Collecting arabic-reshaper
#   Downloading arabic_reshaper-3.0.0-py3-none-any.whl (20 kB)
# Installing collected packages: arabic-reshaper
# Successfully installed arabic-reshaper-3.0.0
# Collecting pycm
#   Downloading pycm-4.0-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.3/70.3 kB 2.7 MB/s eta 0:00:00
# Collecting art>=1.8 (from pycm)
#   Downloading art-6.1-py3-none-any.whl (599 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.8/599.8 kB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from pycm) (1.23.5)
# Installing collected packages: art, pycm
# Successfully installed art-6.1 pycm-4.0

# %%
from bidi.algorithm import get_display
import arabic_reshaper

# %%
def make_farsi_text(x):
    reshaped_text = arabic_reshaper.reshape(x)
    farsi_text = get_display(reshaped_text)
    return farsi_text

# %%
# !git clone https://github.com/mamintoosi/FC2FC.git
# %cd FC2FC
import FC2FC
# Out:
# Cloning into 'FC2FC'...
# remote: Enumerating objects: 4123, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 4123 (delta 9), reused 13 (delta 5), pack-reused 4103
# Receiving objects: 100% (4123/4123), 69.84 MiB | 28.52 MiB/s, done.
# Resolving deltas: 100% (106/106), done.
# /content/FC2FC

# %%
# !rm -r data/Apple/test/Apple_scab/
# !rm -r data/Apple/test/Cedar_apple_rust/
# !rm -r data/Apple/train/Apple_scab/
# !rm -r data/Apple/train/Cedar_apple_rust/
# !rm -r data/Apple/val/Apple_scab/
# !rm -r data/Apple/val/Cedar_apple_rust/

# %%
data_dir = 'data/Apple/'
models_dir = 'models/'

train_dir = os.path.join(data_dir, 'train')
validation_dir = os.path.join(data_dir, 'val')
test_dir = os.path.join(data_dir, 'test')

train_Black_rot_dir = os.path.join(train_dir, 'Black_rot')
train_healthy_dir = os.path.join(train_dir, 'healthy')
validation_Black_rot_dir = os.path.join(validation_dir, 'Black_rot')
validation_healthy_dir = os.path.join(validation_dir, 'healthy')
test_Black_rot_dir = os.path.join(test_dir, 'Black_rot')
test_healthy_dir = os.path.join(test_dir, 'healthy')

inputImSize = 150

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=90,
                                    zoom_range=0.2,
                                    horizontal_flip=True,
                                    vertical_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        # This is the target directory
        train_dir,
        # All images will be resized to 150x150
        target_size=(inputImSize, inputImSize),
        batch_size=64,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(inputImSize, inputImSize),
        batch_size=32,
        class_mode='binary')
test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(inputImSize, inputImSize),
        batch_size=1,
        class_mode='binary')
# Out:
# Found 1812 images belonging to 2 classes.
# Found 226 images belonging to 2 classes.
# Found 228 images belonging to 2 classes.

# %%
1812/2
# Out:
# 906.0

# %%
mdl = 'models/best_model.h5'
checkpoint = ModelCheckpoint(filepath=mdl,
                             monitor='val_loss',
                             verbose=0,
                             save_best_only=True,
                             mode='min')
callbacks = [checkpoint]

# %%
model = FC2FC.seq_model(inputImSize)

# %%
model.compile(loss='binary_crossentropy',
              optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-4),
              metrics=['acc'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Conv1 (Conv2D)              (None, 148, 148, 32)      896
#
#  max_pooling2d_5 (MaxPoolin  (None, 74, 74, 32)        0
#  g2D)
#
#  Conv2 (Conv2D)              (None, 72, 72, 64)        18496
#
#  max_pooling2d_6 (MaxPoolin  (None, 36, 36, 64)        0
#  g2D)
#
#  Conv3 (Conv2D)              (None, 34, 34, 128)       73856
#
#  max_pooling2d_7 (MaxPoolin  (None, 17, 17, 128)       0
#  g2D)
#
#  Conv4 (Conv2D)              (None, 15, 15, 128)       147584
#
#  max_pooling2d_8 (MaxPoolin  (None, 7, 7, 128)         0
#  g2D)
#
#  Conv5 (Conv2D)              (None, 5, 5, 256)         295168
#
#  Conv6 (Conv2D)              (None, 3, 3, 512)         1180160
#
#  max_pooling2d_9 (MaxPoolin  (None, 1, 1, 512)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 1716673 (6.55 MB)
# Trainable params: 1716673 (6.55 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# %%time
epochs = 100
history = model.fit(
          train_generator,
          epochs=epochs,
          validation_data=validation_generator,
          callbacks=callbacks,
          verbose = 1)
# batch_size = 64
# Out:
# Epoch 1/100
# 29/29 [==============================] - 19s 519ms/step - loss: 0.6036 - acc: 0.7196 - val_loss: 0.5819 - val_acc: 0.7257
# Epoch 2/100
# 29/29 [==============================] - 13s 426ms/step - loss: 0.5793 - acc: 0.7263 - val_loss: 0.5364 - val_acc: 0.7257
# Epoch 3/100
# 29/29 [==============================] - 12s 421ms/step - loss: 0.5208 - acc: 0.7445 - val_loss: 0.4521 - val_acc: 0.7788
# Epoch 4/100
# 29/29 [==============================] - 15s 498ms/step - loss: 0.4664 - acc: 0.7958 - val_loss: 0.4548 - val_acc: 0.8097
# Epoch 5/100
# 29/29 [==============================] - 13s 464ms/step - loss: 0.4437 - acc: 0.8019 - val_loss: 0.4255 - val_acc: 0.8274
# Epoch 6/100
# 29/29 [==============================] - 15s 503ms/step - loss: 0.4363 - acc: 0.8140 - val_loss: 0.4050 - val_acc: 0.8407
# Epoch 7/100
# 29/29 [==============================] - 16s 524ms/step - loss: 0.4090 - acc: 0.8228 - val_loss: 0.3383 - val_acc: 0.8761
# Epoch 8/100
# 29/29 [==============================] - 13s 439ms/step - loss: 0.4196 - acc: 0.8146 - val_loss: 0.4427 - val_acc: 0.8230
# Epoch 9/100
# 29/29 [==============================] - 15s 461ms/step - loss: 0.3921 - acc: 0.8295 - val_loss: 0.3485 - val_acc: 0.8540
# Epoch 10/100
# 29/29 [==============================] - 12s 415ms/step - loss: 0.3846 - acc: 0.8372 - val_loss: 0.3475 - val_acc: 0.8584
# Epoch 11/100
# 29/29 [==============================] - 12s 423ms/step - loss: 0.3717 - acc: 0.8433 - val_loss: 0.3847 - val_acc: 0.8540
# Epoch 12/100
# 29/29 [==============================] - 12s 429ms/step - loss: 0.3570 - acc: 0.8499 - val_loss: 0.3572 - val_acc: 0.8628
# Epoch 13/100
# 29/29 [==============================] - 12s 429ms/step - loss: 0.3536 - acc: 0.8526 - val_loss: 0.5157 - val_acc: 0.7965
# Epoch 14/100
# 29/29 [==============================] - 12s 398ms/step - loss: 0.3414 - acc: 0.8675 - val_loss: 0.3591 - val_acc: 0.8451
# Epoch 15/100
# 29/29 [==============================] - 12s 423ms/step - loss: 0.3300 - acc: 0.8648 - val_loss: 0.3005 - val_acc: 0.8805
# Epoch 16/100
# 29/29 [==============================] - 13s 435ms/step - loss: 0.3144 - acc: 0.8780 - val_loss: 0.3051 - val_acc: 0.8761
# Epoch 17/100
# 29/29 [==============================] - 12s 430ms/step - loss: 0.2887 - acc: 0.8913 - val_loss: 0.2362 - val_acc: 0.9204
# Epoch 18/100
# 29/29 [==============================] - 13s 460ms/step - loss: 0.2914 - acc: 0.8825 - val_loss: 0.6160 - val_acc: 0.8009
# Epoch 19/100
# 29/29 [==============================] - 13s 433ms/step - loss: 0.2885 - acc: 0.8836 - val_loss: 0.2073 - val_acc: 0.9336
# Epoch 20/100
# 29/29 [==============================] - 12s 421ms/step - loss: 0.2752 - acc: 0.8951 - val_loss: 0.5280 - val_acc: 0.8142
# Epoch 21/100
# 29/29 [==============================] - 12s 421ms/step - loss: 0.2767 - acc: 0.8940 - val_loss: 0.2423 - val_acc: 0.9071
# Epoch 22/100
# 29/29 [==============================] - 12s 418ms/step - loss: 0.2605 - acc: 0.8985 - val_loss: 0.4805 - val_acc: 0.8319
# Epoch 23/100
# 29/29 [==============================] - 12s 418ms/step - loss: 0.2667 - acc: 0.8951 - val_loss: 0.3947 - val_acc: 0.8496
# Epoch 24/100
# 29/29 [==============================] - 11s 373ms/step - loss: 0.2527 - acc: 0.9007 - val_loss: 0.2789 - val_acc: 0.8894
# Epoch 25/100
# 29/29 [==============================] - 12s 426ms/step - loss: 0.2445 - acc: 0.9084 - val_loss: 0.2053 - val_acc: 0.9159
# Epoch 26/100
# 29/29 [==============================] - 12s 415ms/step - loss: 0.2492 - acc: 0.9051 - val_loss: 0.3516 - val_acc: 0.8673
# Epoch 27/100
# 29/29 [==============================] - 12s 420ms/step - loss: 0.2388 - acc: 0.9117 - val_loss: 0.3364 - val_acc: 0.8673
# Epoch 28/100
# 29/29 [==============================] - 12s 417ms/step - loss: 0.2048 - acc: 0.9244 - val_loss: 0.1998 - val_acc: 0.9292
# Epoch 29/100
# 29/29 [==============================] - 11s 367ms/step - loss: 0.2115 - acc: 0.9167 - val_loss: 0.3643 - val_acc: 0.8761
# Epoch 30/100
# 29/29 [==============================] - 12s 393ms/step - loss: 0.2341 - acc: 0.9117 - val_loss: 0.3544 - val_acc: 0.8717
# Epoch 31/100
# 29/29 [==============================] - 12s 416ms/step - loss: 0.2036 - acc: 0.9172 - val_loss: 0.1672 - val_acc: 0.9425
# Epoch 32/100
# 29/29 [==============================] - 12s 417ms/step - loss: 0.1919 - acc: 0.9249 - val_loss: 0.3667 - val_acc: 0.8584
# Epoch 33/100
# 29/29 [==============================] - 12s 412ms/step - loss: 0.1973 - acc: 0.9272 - val_loss: 0.2024 - val_acc: 0.9336
# Epoch 34/100
# 29/29 [==============================] - 12s 418ms/step - loss: 0.1964 - acc: 0.9249 - val_loss: 0.2396 - val_acc: 0.9071
# Epoch 35/100
# 29/29 [==============================] - 12s 417ms/step - loss: 0.1724 - acc: 0.9316 - val_loss: 0.2676 - val_acc: 0.9027
# Epoch 36/100
# 29/29 [==============================] - 12s 406ms/step - loss: 0.1865 - acc: 0.9283 - val_loss: 0.4964 - val_acc: 0.8584
# Epoch 37/100
# 29/29 [==============================] - 12s 413ms/step - loss: 0.1785 - acc: 0.9316 - val_loss: 0.1409 - val_acc: 0.9425
# Epoch 38/100
# 29/29 [==============================] - 12s 414ms/step - loss: 0.1816 - acc: 0.9305 - val_loss: 0.2244 - val_acc: 0.9204
# Epoch 39/100
# 29/29 [==============================] - 11s 385ms/step - loss: 0.1844 - acc: 0.9299 - val_loss: 0.1455 - val_acc: 0.9469
# Epoch 40/100
# 29/29 [==============================] - 11s 377ms/step - loss: 0.1615 - acc: 0.9387 - val_loss: 0.2021 - val_acc: 0.9248
# Epoch 41/100
# 29/29 [==============================] - 12s 411ms/step - loss: 0.1651 - acc: 0.9393 - val_loss: 0.5908 - val_acc: 0.8319
# Epoch 42/100
# 29/29 [==============================] - 12s 417ms/step - loss: 0.1485 - acc: 0.9398 - val_loss: 0.1824 - val_acc: 0.9425
# Epoch 43/100
# 29/29 [==============================] - 12s 407ms/step - loss: 0.1521 - acc: 0.9404 - val_loss: 0.1483 - val_acc: 0.9425
# Epoch 44/100
# 29/29 [==============================] - 12s 415ms/step - loss: 0.1523 - acc: 0.9426 - val_loss: 0.2572 - val_acc: 0.8982
# Epoch 45/100
# 29/29 [==============================] - 12s 420ms/step - loss: 0.1552 - acc: 0.9376 - val_loss: 0.1535 - val_acc: 0.9558
# Epoch 46/100
# 29/29 [==============================] - 12s 414ms/step - loss: 0.1320 - acc: 0.9547 - val_loss: 0.1191 - val_acc: 0.9469
# Epoch 47/100
# 29/29 [==============================] - 12s 411ms/step - loss: 0.1309 - acc: 0.9525 - val_loss: 0.1708 - val_acc: 0.9425
# Epoch 48/100
# 29/29 [==============================] - 11s 371ms/step - loss: 0.1477 - acc: 0.9432 - val_loss: 0.1930 - val_acc: 0.9336
# Epoch 49/100
# 29/29 [==============================] - 12s 415ms/step - loss: 0.1295 - acc: 0.9525 - val_loss: 0.1050 - val_acc: 0.9558
# Epoch 50/100
# 29/29 [==============================] - 12s 407ms/step - loss: 0.1091 - acc: 0.9619 - val_loss: 0.1572 - val_acc: 0.9602
# Epoch 51/100
# 29/29 [==============================] - 11s 371ms/step - loss: 0.1216 - acc: 0.9564 - val_loss: 0.1213 - val_acc: 0.9558
# Epoch 52/100
# 29/29 [==============================] - 12s 393ms/step - loss: 0.1243 - acc: 0.9547 - val_loss: 0.1952 - val_acc: 0.9381
# Epoch 53/100
# 29/29 [==============================] - 12s 410ms/step - loss: 0.1209 - acc: 0.9520 - val_loss: 0.1145 - val_acc: 0.9602
# Epoch 54/100
# 29/29 [==============================] - 12s 416ms/step - loss: 0.1166 - acc: 0.9542 - val_loss: 0.2994 - val_acc: 0.9248
# Epoch 55/100
# 29/29 [==============================] - 11s 395ms/step - loss: 0.1100 - acc: 0.9536 - val_loss: 0.1060 - val_acc: 0.9602
# Epoch 56/100
# 29/29 [==============================] - 12s 428ms/step - loss: 0.1081 - acc: 0.9608 - val_loss: 0.2976 - val_acc: 0.9071
# Epoch 57/100
# 29/29 [==============================] - 12s 415ms/step - loss: 0.1071 - acc: 0.9592 - val_loss: 0.2292 - val_acc: 0.9381
# Epoch 58/100
# 29/29 [==============================] - 12s 412ms/step - loss: 0.0967 - acc: 0.9663 - val_loss: 0.3373 - val_acc: 0.8894
# Epoch 59/100
# 29/29 [==============================] - 11s 382ms/step - loss: 0.0963 - acc: 0.9647 - val_loss: 0.1209 - val_acc: 0.9646
# Epoch 60/100
# 29/29 [==============================] - 12s 427ms/step - loss: 0.0990 - acc: 0.9647 - val_loss: 0.0791 - val_acc: 0.9690
# Epoch 61/100
# 29/29 [==============================] - 12s 414ms/step - loss: 0.0837 - acc: 0.9696 - val_loss: 0.1287 - val_acc: 0.9779
# Epoch 62/100
# 29/29 [==============================] - 12s 415ms/step - loss: 0.0985 - acc: 0.9652 - val_loss: 0.1017 - val_acc: 0.9735
# Epoch 63/100
# 29/29 [==============================] - 11s 354ms/step - loss: 0.0762 - acc: 0.9741 - val_loss: 0.4717 - val_acc: 0.8850
# Epoch 64/100
# 29/29 [==============================] - 12s 425ms/step - loss: 0.1024 - acc: 0.9592 - val_loss: 0.0533 - val_acc: 0.9779
# Epoch 65/100
# 29/29 [==============================] - 12s 413ms/step - loss: 0.0922 - acc: 0.9658 - val_loss: 0.1527 - val_acc: 0.9513
# Epoch 66/100
# 29/29 [==============================] - 12s 417ms/step - loss: 0.0781 - acc: 0.9713 - val_loss: 0.0722 - val_acc: 0.9646
# Epoch 67/100
# 29/29 [==============================] - 11s 361ms/step - loss: 0.1128 - acc: 0.9592 - val_loss: 0.1241 - val_acc: 0.9735
# Epoch 68/100
# 29/29 [==============================] - 13s 433ms/step - loss: 0.0692 - acc: 0.9752 - val_loss: 0.1951 - val_acc: 0.9381
# Epoch 69/100
# 29/29 [==============================] - 12s 415ms/step - loss: 0.0783 - acc: 0.9713 - val_loss: 0.1468 - val_acc: 0.9336
# Epoch 70/100
# 29/29 [==============================] - 11s 375ms/step - loss: 0.0632 - acc: 0.9774 - val_loss: 0.0940 - val_acc: 0.9735
# Epoch 71/100
# 29/29 [==============================] - 12s 428ms/step - loss: 0.0680 - acc: 0.9746 - val_loss: 0.2669 - val_acc: 0.9159
# Epoch 72/100
# 29/29 [==============================] - 12s 417ms/step - loss: 0.0562 - acc: 0.9829 - val_loss: 0.2391 - val_acc: 0.9336
# Epoch 73/100
# 29/29 [==============================] - 12s 410ms/step - loss: 0.0737 - acc: 0.9730 - val_loss: 0.0851 - val_acc: 0.9602
# Epoch 74/100
# 29/29 [==============================] - 12s 415ms/step - loss: 0.0640 - acc: 0.9779 - val_loss: 0.0924 - val_acc: 0.9735
# Epoch 75/100
# 29/29 [==============================] - 10s 355ms/step - loss: 0.0488 - acc: 0.9812 - val_loss: 0.0862 - val_acc: 0.9823
# Epoch 76/100
# 29/29 [==============================] - 12s 418ms/step - loss: 0.0751 - acc: 0.9713 - val_loss: 0.2401 - val_acc: 0.9469
# Epoch 77/100
# 29/29 [==============================] - 12s 410ms/step - loss: 0.0684 - acc: 0.9752 - val_loss: 0.1371 - val_acc: 0.9735
# Epoch 78/100
# 29/29 [==============================] - 11s 365ms/step - loss: 0.0444 - acc: 0.9868 - val_loss: 0.0989 - val_acc: 0.9779
# Epoch 79/100
# 29/29 [==============================] - 12s 392ms/step - loss: 0.0633 - acc: 0.9785 - val_loss: 0.1601 - val_acc: 0.9513
# Epoch 80/100
# 29/29 [==============================] - 12s 421ms/step - loss: 0.0416 - acc: 0.9823 - val_loss: 0.1421 - val_acc: 0.9690
# Epoch 81/100
# 29/29 [==============================] - 12s 414ms/step - loss: 0.0595 - acc: 0.9746 - val_loss: 0.1627 - val_acc: 0.9558
# Epoch 82/100
# 29/29 [==============================] - 12s 421ms/step - loss: 0.0575 - acc: 0.9779 - val_loss: 0.0979 - val_acc: 0.9779
# Epoch 83/100
# 29/29 [==============================] - 12s 423ms/step - loss: 0.0344 - acc: 0.9868 - val_loss: 0.2285 - val_acc: 0.9558
# Epoch 84/100
# 29/29 [==============================] - 12s 421ms/step - loss: 0.0471 - acc: 0.9834 - val_loss: 0.1877 - val_acc: 0.9690
# Epoch 85/100
# 29/29 [==============================] - 12s 409ms/step - loss: 0.0450 - acc: 0.9834 - val_loss: 0.1690 - val_acc: 0.9646
# Epoch 86/100
# 29/29 [==============================] - 12s 397ms/step - loss: 0.0610 - acc: 0.9823 - val_loss: 0.2290 - val_acc: 0.9381
# Epoch 87/100
# 29/29 [==============================] - 11s 356ms/step - loss: 0.0535 - acc: 0.9823 - val_loss: 0.2004 - val_acc: 0.9646
# Epoch 88/100
# 29/29 [==============================] - 12s 417ms/step - loss: 0.0537 - acc: 0.9796 - val_loss: 0.1030 - val_acc: 0.9735
# Epoch 89/100
# 29/29 [==============================] - 12s 412ms/step - loss: 0.0347 - acc: 0.9901 - val_loss: 0.1472 - val_acc: 0.9513
# Epoch 90/100
# 29/29 [==============================] - 12s 397ms/step - loss: 0.0288 - acc: 0.9901 - val_loss: 0.2341 - val_acc: 0.9513
# Epoch 91/100
# 29/29 [==============================] - 12s 424ms/step - loss: 0.0362 - acc: 0.9857 - val_loss: 0.1346 - val_acc: 0.9735
# Epoch 92/100
# 29/29 [==============================] - 12s 436ms/step - loss: 0.0429 - acc: 0.9845 - val_loss: 0.1068 - val_acc: 0.9779
# Epoch 93/100
# 29/29 [==============================] - 12s 417ms/step - loss: 0.0291 - acc: 0.9890 - val_loss: 0.0613 - val_acc: 0.9823
# Epoch 94/100
# 29/29 [==============================] - 12s 412ms/step - loss: 0.0304 - acc: 0.9912 - val_loss: 0.1718 - val_acc: 0.9735
# Epoch 95/100
# 29/29 [==============================] - 11s 380ms/step - loss: 0.0398 - acc: 0.9823 - val_loss: 0.1718 - val_acc: 0.9690
# Epoch 96/100
# 29/29 [==============================] - 11s 372ms/step - loss: 0.0378 - acc: 0.9879 - val_loss: 0.1083 - val_acc: 0.9779
# Epoch 97/100
# 29/29 [==============================] - 12s 422ms/step - loss: 0.0370 - acc: 0.9857 - val_loss: 0.1944 - val_acc: 0.9735
# Epoch 98/100
# 29/29 [==============================] - 12s 424ms/step - loss: 0.0261 - acc: 0.9884 - val_loss: 0.0470 - val_acc: 0.9823
# Epoch 99/100
# 29/29 [==============================] - 12s 416ms/step - loss: 0.0305 - acc: 0.9912 - val_loss: 0.0835 - val_acc: 0.9779
# Epoch 100/100
# 29/29 [==============================] - 11s 369ms/step - loss: 0.0326 - acc: 0.9901 - val_loss: 0.0238 - val_acc: 0.9912
# CPU times: user 21min 26s, sys: 19.4 s, total: 21min 46s
# Wall time: 23min 49s

# %%
# batch_size = 64
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Valid Loss')
plt.ylabel('Loss')
plt.xlabel('No. epoch')
plt.legend(loc="upper left")
plt.show()

# %%
# !ls -hs models
# Out:
# total 14M
# 14M best_model.h5

# %%
train_generator.batch_size
# Out:
# 64

# %%
# تست مدل اولیه
class_names = ['پوسیدگی سیاه','سالم']
plt.figure(figsize=(10,5))
Black_rotCounter = 0
count = np.zeros(2)
for i in range(100):
    x,y = next(test_generator)
    true_label = int(y[0])
    if count[true_label]>=5:
        continue
    count[true_label]+=1
    yHat = model.predict(x)
    # plt.figure(i)
    # imgplot = plt.imshow(x[0])
    # print(y,yHat)
    plt.subplot(2,5,int(5*true_label+count[true_label]))
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x[0])#, cmap=plt.cm.binary)
    # plt.imshow(xOrigSize[0])#, cmap=plt.cm.binary)
    # predicted_label = np.argmax(predictions_array)
    predicted_label = int(round(yHat[0][0]))
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'
    prob = yHat[0][0] if predicted_label==1 else (1-yHat[0][0])
    plt.xlabel("({:.2f}){}".format(prob,make_farsi_text(class_names[predicted_label])),color=color, fontsize=10)
plt.show()
# Out:
# 1/1 [==============================] - 0s 306ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step

# %%
num_of_test_samples = len(os.listdir(test_Black_rot_dir)) + len(os.listdir(test_healthy_dir))

true_labels = np.zeros((num_of_test_samples,),dtype=int)
predicted_labels = np.zeros((num_of_test_samples,),dtype=int)
for i in range(num_of_test_samples):
    x,y = next(test_generator)
    yHat = model.predict(x)
    true_labels[i] = int(y[0])
    predicted_labels[i] = int(round(yHat[0][0]))

# print(confusion_matrix(true_labels, predicted_labels))
# print(classification_report(true_labels, predicted_labels, target_names=class_names))
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
cm = ConfusionMatrix(actual_vector=true_labels, predict_vector=predicted_labels) # Create CM From Data
cm.plot(cmap=plt.cm.Greens,normalized=False,number_label=True,plot_lib="seaborn")
# print(cm)
print('ACC={:.2f}'.format(cm.Overall_ACC))
print("\t".join("{}:{:.2f}".format(k, v) for k, v in cm.AUC.items()))
print('FNR:{:.2f}, FPR:{:.2f}'.format(cm.FNR_Macro, cm.FPR_Macro))
print('TNR:{:.2f}, TPR:{:.2f}'.format(cm.TNR_Macro, cm.TPR_Macro))
print('F1:{:.2f}'.format(cm.F1_Macro))
# Out:
# ACC=0.98
# 0:0.97	1:0.97
# FNR:0.03, FPR:0.03
# TNR:0.97, TPR:0.97
# F1:0.98

# %%
# تست مدل تمام پیچشی شده
plt.figure(figsize=(10,5))
for i in range(10):
    x,y = next(test_generator)
    convModel = FC2FC.convert_model(model,mdl,[inputImSize,inputImSize])
    yHat = convModel.predict(x)
    # plt.figure(i)
    # imgplot = plt.imshow(x[0])
    # print(y,yHat)
    plt.subplot(2,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x[0])#, cmap=plt.cm.binary)
    # predicted_label = np.argmax(predictions_array)
    true_label = int(y[0])
    # ConvModel Last Layer is different from denseModel Last Layer
    predicted_label = int(round(yHat[0][0][0][0]))
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'
    prob = yHat[0][0] if predicted_label==1 else (1-yHat[0][0])
    plt.xlabel("({:.2f}){}".format(prob[0][0],make_farsi_text(class_names[predicted_label])),color=color, fontsize=10)
plt.show()
# Out:
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 96ms/step
# WARNING:tensorflow:5 out of the last 242 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe6386f6b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 97ms/step
# WARNING:tensorflow:6 out of the last 243 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe6386f6950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step

# %%
convModel.summary()
# Out:
# Model: "FullyConv"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Conv1 (Conv2D)              (None, 148, 148, 32)      896
#
#  MaxPool1 (MaxPooling2D)     (None, 74, 74, 32)        0
#
#  Conv2 (Conv2D)              (None, 72, 72, 64)        18496
#
#  MaxPool2 (MaxPooling2D)     (None, 36, 36, 64)        0
#
#  Conv3 (Conv2D)              (None, 34, 34, 128)       73856
#
#  MaxPool3 (MaxPooling2D)     (None, 17, 17, 128)       0
#
#  Conv4 (Conv2D)              (None, 15, 15, 128)       147584
#
#  MaxPool4 (MaxPooling2D)     (None, 7, 7, 128)         0
#
#  Conv5 (Conv2D)              (None, 5, 5, 256)         295168
#
#  Conv6 (Conv2D)              (None, 3, 3, 512)         1180160
#
#  MaxPool5 (MaxPooling2D)     (None, 1, 1, 512)         0
#
#  lastConv (Conv2D)           (None, 1, 1, 1)           513
#
# =================================================================
# Total params: 1716673 (6.55 MB)
# Trainable params: 1716673 (6.55 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# تست یک تصویر شامل چندین نمونه
fileName = 'data/Black_rot_1_crop.jpg' #https://www.canr.msu.edu/ipm/diseases/black_rot_blossom_end_rot_frogeye_leaf_spot
img = image.load_img(fileName,color_mode='rgb')
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.
# print(file,img_tensor.shape)
x = img_tensor[0]
imSize = [x.shape[0],x.shape[1]]
tmp = [s/inputImSize for s in imSize]
if min(tmp)<1:
    scale = 1/min(tmp)
    newH = int(math.ceil(scale * imSize[0]))
    newW = int(math.ceil(scale * imSize[1]))
    img = image.load_img(fileName,color_mode='rgb',target_size=(newH,newW))
    img_tensor = image.img_to_array(img)
    img_tensor = np.expand_dims(img_tensor, axis=0)
    img_tensor /= 255.
    x = img_tensor[0]
    imSize = [x.shape[0],x.shape[1]]

convModel = FC2FC.convert_model(model,mdl,imSize)

yHat = convModel.predict(img_tensor)
# Out:
# 1/1 [==============================] - 0s 377ms/step

# %%
map = yHat[0][:,:,0]
print(map.shape)
from skimage.transform import resize
map = resize(map, (x.shape[0], x.shape[1]))
from matplotlib import pyplot as plt
plt.imshow(map, interpolation='nearest')
plt.show()
# Out:
# (14, 12)

# %%
fig, ax = plt.subplots(1, 3)
ax[0].imshow(x)
ax[0].imshow(map, cmap='hot', alpha=0.2)
ax[0].axis('off')
ax[1].imshow(map)
ax[1].axis('off')
ax[2].imshow(x)
ax[2].axis('off')
plt.show()
